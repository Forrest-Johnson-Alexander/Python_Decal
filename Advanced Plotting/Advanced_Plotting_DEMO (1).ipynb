# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## SUBPLOTS

#Generating some random data stuff, not important
x = np.linspace(0,2*np.pi, 100)
x_1 = np.linspace(0,100,100)
y1 = 2*np.sin(x)*np.exp(-x)
y2 = np.exp(x/4)
x_scatter = np.linspace(0,100,100)
y1_scatter = (x_scatter) + np.random.randint(low=-50, high=50, size=100)
y2_scatter = x_scatter + np.cos(x)*np.random.random(100)*100

#one figure with 2 columns, and 2 rows
f, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2, figsize=(10,10))

f, ax1.plot(x,y1)
f,ax2.plot(x,y2)
f,ax2.set_title("hello")
f,ax3.scatter(x,y1_scatter)
f,ax4.scatter(x,y2_scatter)
#top right
# YOUR CODE HERE

#middle left
# YOUR CODE HERE

#middle right
# YOUR CODE HERE

f.tight_layout()
plt.show()

# %%
#3D Functions

x,y=np.meshgrid(np.linspace(-5,100000000000,100000000),np.linspace(-5,10000,100))
f = np.sqrt(x**2+y**2)

plt.figure()
plt.imshow(f, cmap = 'plasma')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[33], line 3
#       1 #3D Functions
# ----> 3 x,y=np.meshgrid(np.linspace(-5,100000000000,100000000),np.linspace(-5,10000,100))
#       4 f = np.sqrt(x**2+y**2)
#       6 plt.figure()
#
# File c:\Users\fdrjo\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5164, in meshgrid(copy, sparse, indexing, *xi)
#    5161     output = np.broadcast_arrays(*output, subok=True)
#    5163 if copy:
# -> 5164     output = [x.copy() for x in output]
#    5166 return output
#
# MemoryError: Unable to allocate 74.5 GiB for an array with shape (100, 100000000) and data type float64

# %%
## BAR PLOT
penguins = sns.load_dataset("penguins")
plt.figure()
sns.barplot(data=penguins,x='island',y='body_mass_g')
plt.title("Penguin Homes vs Body Mass")
plt.xlabel("Penguin Home Islands")
plt.ylabel('Average Body Mass')
plt.show()

plt.figure()
sns.barplot()
plt.title("Penguin Homes vs Body Mass")
plt.xlabel("Penguin Home Islands")
plt.ylabel('Average Body Mass')
plt.show()

# %%
## COUNT PLOT
titanic = sns.load_dataset()

plt.figure()
sns.countplot(# YOUR CODE HER)
plt.title("Passenger Class")
plt.xlabel("Class")
plt.ylabel('Number of Passengers')
plt.show()

# %%
titanic['Survived'] = titanic['Survived'].astype(str) # have to convert to string for the legend to appear properly.
sns.countplot(# YOUR CODE HERE)

# %%
# BONUS- BOX PLOT of Titanic Age
sns.boxplot(# YOUR CODE HERE)

# %%
plt.figure()
x = 5
y = 10
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
sns.load_dataset("penguins")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
